# %%
# %matplotlib notebook

# %%
from plot import *

# %%
fibs = fs.load_data("compare_Exp/simData/")
# Out:
# Loading data from 800nm_800μJ_1.01bar_1.38bar_100fs_2.5m_0fs^2_270μmm

# %%
# %matplotlib notebook
fibs100 = fibs.const_param("Tfwhm", 100)
fibs100.list_params()
plot_spect_grid(fibs100, p1= "Energy", p2 = "lambda")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2376">

# %%
# %matplotlib inline
fig = metric_heatmap(fibs100, "Energy", "lambda", "bwidth_ev")

# %%
fibs100.list_metric("bwidth_ev")
# Out:
# [25587.73905066667,
#  25832.449378333335,
#  25756.623643,
#  25677.35128333333,
#  25904.828489333333,
#  25973.760976,
#  26035.800214,
#  26094.392827666663,
#  26152.98544133333,
#  26208.131430666665,
#  26259.83079566666,
#  25594.632299333334,
#  25684.244532,
#  25763.51689166667,
#  25839.342627,
#  25911.721737999997,
#  25977.20760033333,
#  26042.693462666666,
#  26101.286076333334,
#  26159.878689999998,
#  26218.471303666665,
#  26266.724044333332,
#  25604.97217233333,
#  25691.137780666664,
#  25773.856764666667,
#  25846.235875666665,
#  25918.61498666666,
#  25984.100849,
#  26046.140087,
#  26108.179324999997,
#  26166.771938666665,
#  26221.917928,
#  26270.170668666666,
#  25615.312045333332,
#  25698.031029333328,
#  25780.75001333333,
#  25853.129124333336,
#  25925.508235333335,
#  25994.440722,
#  26053.03333566666,
#  26115.07257366666,
#  26173.66518733333,
#  26225.364552333333,
#  26277.06391733333]

# %%
fibs = fs.load_data("../data")
# Out:
# Loading data from 800nm_1600μJ_1.01bar_1.38bar_100fs_2.5m_0fs^2_270μm

# %%
plot_spect_grid(fibs, p1="Energy")
# Out:
# <img src="data:image/png;base64,..." width="300">
# /home/ry/.miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# %matplotlib inline
plot_full_spectrum(fibs.runs[-1])

# %%
fibs.list_metrics()
# Out:
# [{'pwidth': 131.8359375,
#   'bwidth': 148.07226363553514,
#   'bwidth_ev': 0.026976728657,
#   'l_edge': 725.7104261575158,
#   'r_edge': 873.782689793051,
#   'rho_max': 24734955.41342276,
#   'power': 0.7223393127095786},
#  {'pwidth': 148.6083984375,
#   'bwidth': 217.28069842244008,
#   'bwidth_ev': 0.02711804025466667,
#   'l_edge': 689.5423597411256,
#   'r_edge': 906.8230581635656,
#   'rho_max': 1713057105.2125719,
#   'power': 0.7223382110673152},
#  {'pwidth': 115.6494140625,
#   'bwidth': 83.65002722618317,
#   'bwidth_ev': 0.026849203556666666,
#   'l_edge': 759.4153252054116,
#   'r_edge': 843.0653524315948,
#   'rho_max': 14921.991582794823,
#   'power': 0.7223395081854057},
#  {'pwidth': 165.234375,
#   'bwidth': 281.93650633217214,
#   'bwidth_ev': 0.027255905228,
#   'l_edge': 655.611199587626,
#   'r_edge': 937.5477059197981,
#   'rho_max': 31858545118.41356,
#   'power': 0.7223331609520417}]

# %%
a = np.array(fibs.runs[-1].fields)

# %%
a
# Out:
# array([[ 0.00000000e+00+2.26181785e-24j,  0.00000000e+00-3.07409187e-09j,
#         -5.96046448e-08-1.93358041e-09j, ...,
#         -1.49011612e-08+4.25024212e-09j,  1.49011612e-08+1.44959444e-08j,
#         -5.96046448e-08+8.06432325e-09j],
#        [-3.75377896e+03+7.24628347e+03j, -2.57809842e+03+7.84662382e+03j,
#         -1.30549334e+03+8.25501506e+03j, ...,
#         -6.43774071e+03+4.51797747e+03j, -5.70546200e+03+5.55577028e+03j,
#         -4.80429352e+03+6.47448285e+03j],
#        [-3.75377896e+03+7.24628347e+03j, -2.57809842e+03+7.84662382e+03j,
#         -1.30549334e+03+8.25501506e+03j, ...,
#         -6.43774071e+03+4.51797747e+03j, -5.70546200e+03+5.55577028e+03j,
#         -4.80429352e+03+6.47448285e+03j],
#        ...,
#        [-3.75377896e+03+7.24628347e+03j, -2.57809842e+03+7.84662382e+03j,
#         -1.30549334e+03+8.25501506e+03j, ...,
#         -6.43774071e+03+4.51797747e+03j, -5.70546200e+03+5.55577028e+03j,
#         -4.80429352e+03+6.47448285e+03j],
# ...
