# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from plot import *

# %%
fibs = fs.load_data("../data_single/")
# Out:
# [27.157917350516072, 487.1029426923774, 514.2608600428935]μm
# [37.03301338880959, 483.17734134831795, 520.2103547371275]m
# [27.157917350516072, 487.1029426923774, 514.2608600428935]m

# %%
plot_full_spectrum(fibs.runs[0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fibs.runs[0].metrics
# Out:
# {'pwidth': 132.568359375,
#  'bwidth': 27.157917350516072,
#  'l_edge': 487.1029426923774,
#  'r_edge': 514.2608600428935,
#  'rho_max': 70736.83726731675,
#  'power': 0.7223395188953665}

# %%
# %matplotlib inline
fig = metric_heatmap(fibs, "Energy", "Tfwhm", "bwidth")
