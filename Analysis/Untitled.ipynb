# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from plot import *

# %%
fibs = fs.load_data("../data")
# Out:
# Loading data from 600nm_75μJ_0.01bar_90fs_2.5m_0fs^2_400μmmm

# %%
fibs270 = fibs.const_param("fiberD", 270E-6)
fibs400 = fibs.const_param("fiberD", 400E-6)

# %%
metric_heatmap(fibs270.const_param("Tfwhm", 80), "Energy", "lambda", "bwidth")

# %%
plt.plot()

# %%
metric_heatmap(fibs270.const_param("Tfwhm", 90), "Energy", "lambda", "bwidth")

# %%
metric_heatmap(fibs270.const_param("Tfwhm", 100), "Energy", "lambda", "bwidth")

# %%
plot_spect_grid(fibs270.const_param("Tfwhm", 80), "Energy", "lambda")
